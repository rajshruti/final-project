# %%
# Import dependencies

import pandas as pd

# %%
# Read all the necessary files

att1 = pd.read_csv("../Data/Attendance/StudentAttendance_Jan.csv")
att2 = pd.read_csv("../Data/Attendance/StudentAttendance_Feb.csv")
att3 = pd.read_csv("../Data/Attendance/StudentAttendance_Mar.csv")
att4 = pd.read_csv("../Data/Attendance/StudentAttendance_Apr.csv")
att5 = pd.read_csv("../Data/Attendance/StudentAttendance_May.csv")
att6 = pd.read_csv("../Data/Attendance/StudentAttendance_June.csv")
att7 = pd.read_csv("../Data/Attendance/StudentAttendance_July.csv")
att8 = pd.read_csv("../Data/Attendance/StudentAttendance_Aug.csv")
att9 = pd.read_csv("../Data/Attendance/StudentAttendance_Sep.csv")
att10 = pd.read_csv("../Data/Attendance/StudentAttendance_Oct.csv")
#att11 = pd.read_csv("../Data/Attendance/StudentAttendance_Nov.csv")
att12 = pd.read_csv("../Data/Attendance/StudentAttendance_Dec.csv")
comp1 = pd.read_csv("../Data/For ML/StudentCompletionSummaryOffline_Jan.csv")
comp2 = pd.read_csv("../Data/For ML/StudentCompletionSummaryOffline_Feb.csv")
comp3 = pd.read_csv("../Data/For ML/StudentCompletionSummaryOffline_Mar.csv")
comp4 = pd.read_csv("../Data/For ML/StudentCompletionSummaryOffline_Apr.csv")
comp5 = pd.read_csv("../Data/For ML/StudentCompletionSummaryOffline_May.csv")
comp6 = pd.read_csv("../Data/For ML/StudentCompletionSummaryOffline_Jun.csv")
comp7 = pd.read_csv("../Data/For ML/StudentCompletionSummaryOffline_Jul.csv")
comp8 = pd.read_csv("../Data/For ML/StudentCompletionSummaryOffline_Aug.csv")
comp9 = pd.read_csv("../Data/For ML/StudentCompletionSummaryOffline_Sep.csv")
comp10 = pd.read_csv("../Data/For ML/StudentCompletionSummaryOffline_Oct.csv")
comp11 = pd.read_csv("../Data/For ML/StudentCompletionSummaryOffline_Nov.csv")
comp12 = pd.read_csv("../Data/For ML/StudentCompletionSummaryOffline_Dec.csv")

# %%
# Keep required columns in 'att' dataframes using loc 

att1 = att1.loc[:, ["ContractCode","TimeIn","attendanceid","TotalTime","contractstartdate","scheduledenddate","FundingSourceName"]]
att2 = att2.loc[:, ["ContractCode","TimeIn","attendanceid","TotalTime","contractstartdate","scheduledenddate","FundingSourceName"]]
att3 = att3.loc[:, ["ContractCode","TimeIn","attendanceid","TotalTime","contractstartdate","scheduledenddate","FundingSourceName"]]
att4 = att4.loc[:, ["ContractCode","TimeIn","attendanceid","TotalTime","contractstartdate","scheduledenddate","FundingSourceName"]]
att5 = att5.loc[:, ["ContractCode","TimeIn","attendanceid","TotalTime","contractstartdate","scheduledenddate","FundingSourceName"]]
att6 = att6.loc[:, ["ContractCode","TimeIn","attendanceid","TotalTime","contractstartdate","scheduledenddate","FundingSourceName"]]
att7 = att7.loc[:, ["ContractCode","TimeIn","attendanceid","TotalTime","contractstartdate","scheduledenddate","FundingSourceName"]]
att8 = att8.loc[:, ["ContractCode","TimeIn","attendanceid","TotalTime","contractstartdate","scheduledenddate","FundingSourceName"]]
att9 = att9.loc[:, ["ContractCode","TimeIn","attendanceid","TotalTime","contractstartdate","scheduledenddate","FundingSourceName"]]
att10 = att10.loc[:, ["ContractCode","TimeIn","attendanceid","TotalTime","contractstartdate","scheduledenddate","FundingSourceName"]]
#att11 = att11.loc[:, ["ContractCode","TimeIn","attendanceid","TotalTime","contractstartdate","scheduledenddate","FundingSourceName"]]
att12 = att12.loc[:, ["ContractCode","TimeIn","attendanceid","TotalTime","contractstartdate","scheduledenddate","FundingSourceName"]]

# %%
# Rename column called 'SortField' in 'att' dataframes as 'Date'

att1 = att1.rename(columns={"TimeIn" : "Date"})
att2 = att2.rename(columns={"TimeIn" : "Date"})
att3 = att3.rename(columns={"TimeIn" : "Date"})
att4 = att4.rename(columns={"TimeIn" : "Date"})
att5 = att5.rename(columns={"TimeIn" : "Date"})
att6 = att6.rename(columns={"TimeIn" : "Date"})
att7 = att7.rename(columns={"TimeIn" : "Date"})
att8 = att8.rename(columns={"TimeIn" : "Date"})
att9 = att9.rename(columns={"TimeIn" : "Date"})
att10 = att10.rename(columns={"TimeIn" : "Date"})
#att11 = att11.rename(columns={"TimeIn" : "Date"})
att12 = att12.rename(columns={"TimeIn" : "Date"})

# %%
# Create a new column called 'Month' in 'att' dataframes

att1['Month'] = 'January'
att2['Month'] = 'February'
att3['Month'] = 'March'
att4['Month'] = 'April'
att5['Month'] = 'May'
att6['Month'] = 'June'
att7['Month'] = 'July'
att8['Month'] = 'August'
att9['Month'] = 'September'
att10['Month'] = 'October'
#att11['Month'] = 'November'
att12['Month'] = 'December'

# %%
# Merge all dataframes (except dfA11) in 'att' dataframes

frames = [att1,att2,att3,att4,att5,att6,att7,att8,att9,att10,att12]
merged_att = pd.concat(frames)

# %%
# Reindex the dataframe in 'att' dataframes

merged_att.index = pd.RangeIndex(len(merged_att.index))

# %%
# Drop NA rows in merged_att

merged_att = merged_att.dropna(axis=0, thresh=8)

# %%
merged_att.head()
# Out:
#   ContractCode        Date  attendanceid  TotalTime contractstartdate  \
# 0      V149497  2019-01-07      10573177        307        2018-11-12
# 1      V149433  2019-01-07      10573180        314        2018-10-22
# 2      V149523  2019-01-07      10573178        252        2018-11-26
# 3      V149291  2019-01-07      10573182        291        2018-08-27
# 4      V149220  2019-01-07      10573181        410        2018-09-17
#
#   scheduledenddate  FundingSourceName    Month
# 0       2019-11-15  Self Paid/Private  January
# 1       2019-11-08               OSAP  January
# 2       2019-11-29  Self Paid/Private  January
# 3       2019-03-29               OSAP  January
# 4       2019-09-06               OSAP  January

# %%
# Rename comp dataframes 'Contract #' column

comp1 = comp1.rename(columns={"Contract #" : "ContractCode"})
comp2 = comp2.rename(columns={"Contract #" : "ContractCode"})
comp3 = comp3.rename(columns={"Contract #" : "ContractCode"})
comp4 = comp4.rename(columns={"Contract #" : "ContractCode"})
comp5 = comp5.rename(columns={"Contract #" : "ContractCode"})
comp6 = comp6.rename(columns={"Contract #" : "ContractCode"})
comp7 = comp7.rename(columns={"Contract #" : "ContractCode"})
comp8 = comp8.rename(columns={"Contract #" : "ContractCode"})
comp9 = comp9.rename(columns={"Contract #" : "ContractCode"})
comp10 = comp10.rename(columns={"Contract #" : "ContractCode"})
comp11 = comp11.rename(columns={"Contract #" : "ContractCode"})
comp12 = comp12.rename(columns={"Contract #" : "ContractCode"})

# %%
# Merge comp1 and merged_att using an inner join

merge1 = pd.merge(merged_att, comp1, on="ContractCode")
merge2 = pd.merge(merged_att, comp2, on="ContractCode")
merge3 = pd.merge(merged_att, comp3, on="ContractCode")
merge4 = pd.merge(merged_att, comp4, on="ContractCode")
merge5 = pd.merge(merged_att, comp5, on="ContractCode")
merge6 = pd.merge(merged_att, comp6, on="ContractCode")
merge7 = pd.merge(merged_att, comp7, on="ContractCode")
merge8 = pd.merge(merged_att, comp8, on="ContractCode")
merge9 = pd.merge(merged_att, comp9, on="ContractCode")
merge10 = pd.merge(merged_att, comp10, on="ContractCode")
merge11 = pd.merge(merged_att, comp11, on="ContractCode")
merge12 = pd.merge(merged_att, comp12, on="ContractCode")

# %%
# Merge all 'merge' dataframes

merge_frames = [merge1,merge2,merge3,merge4,merge5,merge6,merge7,merge8,merge9,merge10,merge11,merge12]
ml_data = pd.concat(merge_frames)

# %%
# Reindex 'ml_data' dataframe

ml_data.index = pd.RangeIndex(len(ml_data.index))

# %%
ml_data
# Out:
#       ContractCode        Date  attendanceid  TotalTime contractstartdate  \
# 0          V149081  2019-01-07      10573575        380        2018-01-23
# 1          V149081  2019-01-08      10575778        115        2018-01-23
# 2          V149081  2019-01-10      10577982        539        2018-01-23
# 3          V149081  2019-01-14      10580864        511        2018-01-23
# 4          V149081  2019-01-15      10582639        554        2018-01-23
# 5          V149081  2019-01-17      10585767        455        2018-01-23
# 6          V149081  2019-01-18      10587446        167        2018-01-23
# 7          V149491  2019-01-07      10573864        365        2018-11-07
# 8          V149491  2019-01-08      10575585        391        2018-11-07
# 9          V149491  2019-01-09      10577345        305        2018-11-07
# 10         V149491  2019-01-10      10578896        346        2018-11-07
# 11         V149491  2019-01-14      10581738        102        2018-11-07
# ...
